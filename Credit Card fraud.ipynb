# %%
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns
import numpy as np 
from numba import jit
# Out:
# c:\Users\gersh\anaconda3\envs\Lab\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
user_tag= pd.read_csv('train_tag.csv')

# %%
user_tag.head(10)
# Out:
#         id  flag gdr_cd  age mrg_situ_cd edu_deg_cd acdm_deg_cd deg_cd  \
# 0  U7A4BAD     0      M   41           B          B           Z    NaN
# 1  U557810     0      M   35           A        NaN           G    NaN
# 2  U1E9240     0      M   53           B          A           C      C
# 3  U6DED00     0      F   41           B        NaN           Z    NaN
# 4  UDA8E28     0      F   42           B          B           Z      B
# 5  UE2EC3C     0      F   48           B          C          31    NaN
# 6  UCEC228     0      F   39           A          B          30    NaN
# 7  U2E6C29     1      M   66           B          C           Z      A
# 8  UB67E38     0      F   39           B          C          31    NaN
# 9  UF09E80     0      M   48           B          B          30      B
#
#   job_year ic_ind  ... hld_crd_card_grd_cd crd_card_act_ind  \
# 0        3      0  ...                  -1                0
# 1        4      0  ...                  -1                0
# ...

# %%
user_tag.dtypes
# Out:
# id                                 object
# flag                                int64
# gdr_cd                             object
# age                                 int64
# mrg_situ_cd                        object
# edu_deg_cd                         object
# acdm_deg_cd                        object
# deg_cd                             object
# job_year                           object
# ic_ind                             object
# fr_or_sh_ind                       object
# dnl_mbl_bnk_ind                    object
# dnl_bind_cmb_lif_ind               object
# hav_car_grp_ind                    object
# hav_hou_grp_ind                    object
# l6mon_agn_ind                      object
# frs_agn_dt_cnt                     object
# vld_rsk_ases_ind                   object
# fin_rsk_ases_grd_cd                object
# confirm_rsk_ases_lvl_typ_cd        object
# cust_inv_rsk_endu_lvl_cd           object
# l6mon_daim_aum_cd                   int64
# ...

# %%
del user_tag['edu_deg_cd']

# %%
user_tag.head(10)
# Out:
#         id  flag gdr_cd  age mrg_situ_cd acdm_deg_cd deg_cd job_year ic_ind  \
# 0  U7A4BAD     0      M   41           B           Z    NaN        3      0
# 1  U557810     0      M   35           A           G    NaN        4      0
# 2  U1E9240     0      M   53           B           C      C        9      0
# 3  U6DED00     0      F   41           B           Z    NaN        0      0
# 4  UDA8E28     0      F   42           B           Z      B        3      1
# 5  UE2EC3C     0      F   48           B          31    NaN        8      0
# 6  UCEC228     0      F   39           A          30    NaN        2      0
# 7  U2E6C29     1      M   66           B           Z      A       30      0
# 8  UB67E38     0      F   39           B          31    NaN        1      0
# 9  UF09E80     0      M   48           B          30      B        7      1
#
#   fr_or_sh_ind  ... hld_crd_card_grd_cd crd_card_act_ind  \
# 0            0  ...                  -1                0
# ...

# %%
del user_tag['acdm_deg_cd'] 
del user_tag['deg_cd'] 
del user_tag['mrg_situ_cd'] 
del user_tag['ic_ind'] 
del user_tag['hav_car_grp_ind'] 
del user_tag['hld_crd_card_grd_cd'] 

user_tag.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gersh\anaconda3\envs\Lab\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\gersh\anaconda3\envs\Lab\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\gersh\anaconda3\envs\Lab\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'acdm_deg_cd'
#
# The above exception was the direct cause of the following exception:
#
# ...
